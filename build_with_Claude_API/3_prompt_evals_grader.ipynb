# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6.666666666666667

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS S3 Bucket Name Parser\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef parse_s3_bucket_name(s3_uri: str) -> str:\n    \"\"\"\n    Parse an AWS S3 bucket name from a full S3 URI.\n    \n    Args:\n        s3_uri: Full S3 URI (e.g., 's3://my-bucket/path/to/object')\n    \n    Returns:\n        The bucket name (e.g., 'my-bucket')\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(\"Invalid S3 URI: must start with 's3://'\")\n    \n    # Remove 's3://' prefix\n    path = s3_uri[5:]\n    \n    # Split by '/' and get the first part (bucket name)\n    bucket_name = path.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Invalid S3 URI: bucket name is empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        ('s3://my-bucket/path/to/object', 'my-bucket'),\n        ('s3://my-bucket/', 'my-bucket'),\n        ('s3://my-bucket', 'my-bucket'),\n        ('s3://bucket-123/folder/file.txt', 'bucket-123'),\n        ('s3://a/b/c/d/e', 'a'),\n    ]\n    \n    for uri, expected in test_cases:\n        result = parse_s3_bucket_name(uri)\n        status = \"\u2713\" if result == expected else \"\u2717\"\n        print(f\"{status} Input: {uri}\")\n        print(f\"  Expected: {expected}, Got: {result}\\n\")\n```\n\n**Output:**\n```\n\u2713 Input: s3://my-bucket/path/to/object\n  Expected: my-bucket, Got: my-bucket\n\n\u2713 Input: s3://my-bucket/\n  Expected: my-bucket, Got: my-bucket\n\n\u2713 Input: s3://my-bucket\n  Expected: my-bucket, Got: my-bucket\n\n\u2713 Input: s3://bucket-123/folder/file.txt\n  Expected: bucket-123, Got: bucket-123\n\n\u2713 Input: s3://a/b/c/d/e\n  Expected: a, Got: a\n```\n\n## Alternative Solution Using Regex\n\n```python\nimport re\n\ndef parse_s3_bucket_name_regex(s3_uri: str) -> str:\n    \"\"\"Parse S3 bucket name using regex.\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if not match:\n        raise ValueError(\"Invalid S3 URI format\")\n    return match.group(1)\n```\n\n## Key Points:\n\n- **Simple approach**: Remove the `s3://` prefix and split by `/`\n- **Regex approach**: Use pattern `s3://([^/]+)` to match bucket name\n- **Error handling**: Validates the URI format\n- **Edge cases handled**: Works with or without trailing slashes and paths\n\nChoose the solution that best fits your use case!",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from a full S3 URI (e.g., 's3://my-bucket/path/to/object') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution correctly solves the stated problem with clean, maintainable code and good documentation. However, it lacks AWS S3 URI specification compliance for bucket name validation and doesn't handle alternative S3 URI formats that are valid in AWS contexts. The error handling is adequate for the basic use case but could be more robust for production code. The multiple solution approaches are helpful, though the regex alternative is underutilized (not tested)."
#   },
#   {
#     "output": "# AWS Lambda CloudFormation Template Snippet\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template for AWS Lambda function\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"MyLambdaFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"my-lambda-function\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello from Lambda!'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Description\": \"ARN of the Lambda function\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"MyLambdaFunction\",\n          \"Arn\"\n        ]\n      }\n    },\n    \"LambdaFunctionName\": {\n      \"Description\": \"Name of the Lambda function\",\n      \"Value\": {\n        \"Ref\": \"MyLambdaFunction\"\n      }\n    }\n  }\n}\n```\n\n## Key Components:\n\n| Component | Description |\n|-----------|-------------|\n| **FunctionName** | `my-lambda-function` - The logical name of the Lambda function |\n| **Runtime** | `python3.11` - Python 3.11 runtime environment |\n| **Role** | IAM role ARN that grants Lambda permissions (using Fn::GetAtt) |\n| **Handler** | `index.lambda_handler` - Entry point for the function |\n| **Code** | Inline Python code with a basic handler function |\n| **IAM Role** | Includes basic Lambda execution permissions for CloudWatch Logs |\n\n## Alternative: Using Placeholder IAM Role ARN\n\nIf you prefer to use a hardcoded placeholder ARN:\n\n```json\n\"MyLambdaFunction\": {\n  \"Type\": \"AWS::Lambda::Function\",\n  \"Properties\": {\n    \"FunctionName\": \"my-lambda-function\",\n    \"Runtime\": \"python3.11\",\n    \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n    \"Handler\": \"index.lambda_handler\",\n    \"Code\": {\n      \"ZipFile\": \"def lambda_handler(event, context):\\n    return {'statusCode': 200}\\n\"\n    }\n  }\n}\n```\n\nThis template is production-ready and includes proper error handling with CloudWatch Logs integration.",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet that defines an AWS Lambda function with basic properties including function name, runtime (Python 3.11), and a placeholder IAM role ARN",
#       "format": "json"
#     },
#     "score": 7,
#     "reasoning": "The solution exceeds the original requirements in scope (which asked for a snippet with placeholder ARN) by providing a full working template with IAM role definition. While this is more helpful overall, it doesn't precisely match the stated task. The solution is technically correct and well-documented, but conflates development convenience features with production readiness. The alternative section shows awareness of the placeholder requirement but should be primary rather than secondary."
#   },
#   {
#     "output": "# AWS EC2 Instance ID Validator\n\nHere's a Python function that validates AWS EC2 instance IDs:\n\n```python\nimport re\n\ndef is_valid_ec2_instance_id(instance_id):\n    \"\"\"\n    Validates if a string matches the valid AWS EC2 instance ID format.\n    \n    Valid format: 'i-' followed by either:\n    - 8 hexadecimal characters (older instances)\n    - 17 hexadecimal characters (newer instances)\n    \n    Args:\n        instance_id (str): The instance ID to validate\n        \n    Returns:\n        bool: True if the instance ID matches the valid format, False otherwise\n        \n    Examples:\n        >>> is_valid_ec2_instance_id(\"i-0a1b2c3d\")\n        True\n        >>> is_valid_ec2_instance_id(\"i-0a1b2c3d4e5f6g7h8\")\n        False\n        >>> is_valid_ec2_instance_id(\"i-0a1b2c3d4e5f6a7h8i9j0k1l2m\")\n        True\n        >>> is_valid_ec2_instance_id(\"invalid-id\")\n        False\n    \"\"\"\n    # Pattern explanation:\n    # ^i-           : Start with 'i-'\n    # (?:           : Non-capturing group for either pattern\n    #   [0-9a-f]{8}  : 8 hexadecimal characters (0-9, a-f)\n    #   |            : OR\n    #   [0-9a-f]{17} : 17 hexadecimal characters\n    # )$            : End of string\n    \n    pattern = r'^i-(?:[0-9a-f]{8}|[0-9a-f]{17})$'\n    return bool(re.match(pattern, instance_id, re.IGNORECASE))\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        (\"i-0a1b2c3d\", True),                          # Valid 8-char format\n        (\"i-1234abcd\", True),                          # Valid 8-char format\n        (\"i-0a1b2c3d4e5f6a7h8i9j0k1l2m\", True),       # Valid 17-char format\n        (\"i-0a1b2c3d4e5f6a7h8i9j0k1l2\", False),       # Invalid length (16 chars)\n        (\"i-0a1b2c3d4e5f6a7h8i9j0k1l2m3\", False),     # Invalid length (18 chars)\n        (\"i-0a1b2c3g\", False),                         # Invalid hex character 'g'\n        (\"0a1b2c3d\", False),                           # Missing 'i-' prefix\n        (\"i-0A1B2C3D\", True),                          # Valid with uppercase\n        (\"i-\", False),                                 # Missing hex characters\n        (\"invalid-id\", False),                         # Wrong format\n        (\"i-0a1b2c3d \", False),                        # Trailing space\n        (\"\", False),                                   # Empty string\n        (None, False),                                 # None input (needs handling)\n    ]\n    \n    print(\"Testing AWS EC2 Instance ID Validator\\n\")\n    for instance_id, expected in test_cases:\n        try:\n            result = is_valid_ec2_instance_id(instance_id)\n            status = \"\u2713\" if result == expected else \"\u2717\"\n            print(f\"{status} '{instance_id}' -> {result} (expected: {expected})\")\n        except (TypeError, AttributeError) as e:\n            print(f\"\u2717 '{instance_id}' -> Error: {e}\")\n```\n\n## Enhanced Version with Error Handling\n\nIf you want a more robust version that handles edge cases:\n\n```python\nimport re\nfrom typing import Union\n\ndef is_valid_ec2_instance_id(instance_id: Union[str, None])",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS EC2 instance ID as input and returns True if it matches the valid AWS instance ID format (i-followed by 8 or 17 hexadecimal characters)",
#       "format": "python"
#     },
#     "score": 6,
#     "reasoning": "The core solution is functionally sound with correct regex pattern and good documentation. However, the solution is incomplete with an unfinished enhanced version section, and there are logical inconsistencies in the test cases themselves (the 17-char test has invalid hex characters and doesn't match the claimed length). The basic function also doesn't handle None gracefully despite testing for it. These issues suggest incomplete implementation and insufficient test validation."
#   }
# ]
