# %%
# Install the Anthropic SDK if needed
# !pip install anthropic -q
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import anthropic

# ── Your API key ────────────────────────────────────────────────
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic

client  = Anthropic()

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages,model="claude-haiku-4-5", system=None):
    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages
    }
    if system:
        params["system"] = system 
    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(
    messages,
     "Write a Python function that checks a string for duplicate characters.")
answer=chat(messages, system="You are a Python Engineer who writes very concise code")

answer
# Out:
# '# Simple and concise ways to check for duplicate characters:\n\n```python\n# Method 1: Using set (most efficient)\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n\n# Method 2: Using dict.fromkeys (preserves order)\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(dict.fromkeys(s))\n\n# Method 3: Return first duplicate character found\ndef has_duplicates(s: str) -> str | bool:\n    seen = set()\n    for char in s:\n        if char in seen:\n            return char\n        seen.add(char)\n    return False\n```\n\n**Usage examples:**\n```python\nhas_duplicates("hello")      # True (l, l)\nhas_duplicates("world")      # False\nhas_duplicates("aabbcc")     # True (a)\n\n# Method 3 output:\nhas_duplicates("hello")      # \'l\'\nhas_duplicates("world")      # False\n```\n\n**Performance:** O(n) time, O(n) space. Method 1 is fastest for most cases.'
