# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects."""
    messages = []
    add_user_message(messages,prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json","w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
    Please solve the following task:
    {test_case["task"]}
    """

    messages = []
    add_user_message(messages,prompt)
    output = chat(messages)
    return(output)

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    #TODO - Grading
    score =10
    return {
        "output": output,
        "test_case":test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# AWS Account ID Extractor from ARN\n\nHere's a comprehensive solution with multiple approaches:\n\n## Solution 1: Simple and Straightforward\n\n```python\ndef extract_account_id_from_arn(arn: str) -> str | None:\n    \"\"\"\n    Extracts the AWS account ID from an ARN string.\n    \n    Args:\n        arn: An Amazon Resource Name (ARN) string\n        \n    Returns:\n        The 12-digit account ID if present, None otherwise\n        \n    Examples:\n        >>> extract_account_id_from_arn('arn:aws:s3:::my-bucket')\n        None\n        >>> extract_account_id_from_arn('arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0')\n        '123456789012'\n    \"\"\"\n    try:\n        # ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n        parts = arn.split(':')\n        \n        # Account ID is at index 4 (0-indexed)\n        if len(parts) >= 5:\n            account_id = parts[4]\n            # Return account ID only if it's not empty (some ARNs don't have account IDs)\n            return account_id if account_id else None\n    except (IndexError, AttributeError):\n        pass\n    \n    return None\n```\n\n## Solution 2: Using Regular Expressions (More Robust)\n\n```python\nimport re\n\ndef extract_account_id_from_arn_regex(arn: str) -> str | None:\n    \"\"\"\n    Extracts the AWS account ID from an ARN string using regex.\n    \n    Args:\n        arn: An Amazon Resource Name (ARN) string\n        \n    Returns:\n        The 12-digit account ID if present, None otherwise\n    \"\"\"\n    # Match ARN pattern with optional account ID\n    # Account ID should be 12 digits\n    pattern = r'^arn:aws[^:]*:[^:]*:[^:]*:(\\d{12}):'\n    \n    match = re.search(pattern, arn)\n    return match.group(1) if match else None\n```\n\n## Solution 3: Enhanced with Type Hints and Validation\n\n```python\nfrom typing import Optional\nimport re\n\ndef extract_account_id_from_arn_enhanced(arn: str) -> Optional[str]:\n    \"\"\"\n    Extracts and validates the AWS account ID from an ARN string.\n    \n    Args:\n        arn: An Amazon Resource Name (ARN) string\n        \n    Returns:\n        The 12-digit account ID if present and valid, None otherwise\n        \n    Raises:\n        TypeError: If arn is not a string\n    \"\"\"\n    if not isinstance(arn, str):\n        raise TypeError(f\"Expected string, got {type(arn).__name__}\")\n    \n    if not arn.startswith('arn:'):\n        return None\n    \n    try:\n        parts = arn.split(':')\n        if len(parts) < 5:\n            return None\n        \n        account_id = parts[4]\n        \n        # Validate: account ID should be exactly 12 digits or empty\n        if account_id and (not account_id.isdigit() or len(account_id) != 12):\n            return None\n        \n        return account_id if account_id else None\n    except Exception:\n        return None\n```\n\n## Complete Test Suite\n\n```python\ndef test_extract_account_id():\n    \"\"\"Test the account ID extraction function.\"\"\"\n    \n    # Test cases: (input, expected_output)\n    test_cases = [\n        # S3 bucket ARN (no account ID)\n        ('arn:aws:s3:::my-bucket', None),\n        ('arn:aws:s3:::my-bucket/*', None),\n        \n        # EC2 instance ARN (with account ID)\n        ('arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0', '123456789012'),\n        \n        # IA",
#     "test_case": {
#       "task": "Write a Python function that extracts the AWS account ID from an ARN (Amazon Resource Name) string. The function should take an ARN like 'arn:aws:s3:::my-bucket' or 'arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0' and return the account ID if present, or None if the ARN doesn't contain an account ID."
#     },
#     "score": 10
#   },
#   {
#     "output": "```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"AllowListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-data-bucket\"\n      ]\n    },\n    {\n      \"Sid\": \"AllowGetObject\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-data-bucket/*\"\n      ]\n    }\n  ]\n}\n```\n\n**Explanation of the policy structure:**\n\n- **Version**: `\"2012-10-17\"` - The latest IAM policy language version (required)\n\n- **Statement**: An array containing policy rules\n\n- **Sid** (Statement ID): Optional but recommended identifier for each statement (improves readability)\n\n- **Effect**: `\"Allow\"` - Grants permission for the specified actions\n\n- **Action**: The S3 actions being permitted:\n  - `s3:ListBucket` - Allows listing objects in the bucket\n  - `s3:GetObject` - Allows retrieving/downloading objects from the bucket\n\n- **Resource**: Specifies which AWS resources the policy applies to:\n  - `arn:aws:s3:::my-data-bucket` - For ListBucket (bucket itself)\n  - `arn:aws:s3:::my-data-bucket/*` - For GetObject (all objects in the bucket)\n\n**Note**: The two statements use different resource ARNs because:\n- `ListBucket` permission is applied at the **bucket level**\n- `GetObject` permission is applied at the **object level** (indicated by `/*`)",
#     "test_case": {
#       "task": "Create a JSON object representing an AWS IAM policy that allows a principal to perform the s3:GetObject and s3:ListBucket actions on a specific S3 bucket named 'my-data-bucket'. The policy should include proper Version, Statement, Effect, Action, and Resource fields."
#     },
#     "score": 10
#   },
#   {
#     "output": "# AWS S3 Bucket Name Regex\n\nHere's a comprehensive regular expression that matches valid AWS S3 bucket names:\n\n```regex\n^(?!.*\\d+\\.\\d+\\.\\d+\\.\\d+$)(?!-)[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$|^[a-z0-9]$\n```\n\n## Breakdown\n\nLet me explain each component:\n\n```regex\n^                          # Start of string\n(?!.*\\d+\\.\\d+\\.\\d+\\.\\d+$) # Negative lookahead: reject IP address format\n(?!-)                      # Negative lookahead: first char cannot be hyphen\n[a-z0-9]                   # First character must be letter or number\n[a-z0-9.-]{1,61}           # Middle characters (1-61 chars): letters, numbers, hyphens, periods\n[a-z0-9]                   # Last character must be letter or number\n$                          # End of string\n|\n^[a-z0-9]$                 # OR: single character (edge case for 1-char bucket)\n```\n\n## Better Alternative (More Readable)\n\nIf you prefer a more maintainable version:\n\n```regex\n^(?!(\\d{1,3}\\.){3}\\d{1,3}$)(?!-)(?!.*-$)[a-z0-9]([a-z0-9.-]{0,61}[a-z0-9])?$\n```\n\n## Validation Rules Covered\n\n\u2705 Length: 3-63 characters (or 1-63 with alternative)  \n\u2705 Character set: lowercase letters, numbers, hyphens, periods  \n\u2705 Starts with: letter or number (not hyphen)  \n\u2705 Ends with: letter or number (not hyphen or period)  \n\u2705 Rejects: IP address format (e.g., 192.168.1.1)  \n\n## Testing Examples\n\n```javascript\nconst regex = /^(?!.*\\d+\\.\\d+\\.\\d+\\.\\d+$)(?!-)[a-z0-9][a-z0-9.-]{1,61}[a-z0-9]$|^[a-z0-9]$/;\n\n// Valid\nconsole.log(regex.test(\"my-bucket\"));           // true\nconsole.log(regex.test(\"bucket.name\"));         // true\nconsole.log(regex.test(\"mybucket123\"));         // true\nconsole.log(regex.test(\"a\"));                   // true\n\n// Invalid\nconsole.log(regex.test(\"My-Bucket\"));           // false (uppercase)\nconsole.log(regex.test(\"-bucket\"));             // false (starts with hyphen)\nconsole.log(regex.test(\"bucket-\"));             // false (ends with hyphen)\nconsole.log(regex.test(\"192.168.1.1\"));         // false (IP format)\nconsole.log(regex.test(\"ab\"));                  // false (too short)\n```\n\nChoose the first regex for strict compliance or the second for better readability depending on your use case!",
#     "test_case": {
#       "task": "Write a regular expression that matches valid AWS S3 bucket names. The bucket name should be 3-63 characters long, contain only lowercase letters, numbers, hyphens, and periods, start and end with a letter or number, and not be formatted as an IP address (e.g., not like 192.168.1.1)."
#     },
#     "score": 10
#   }
# ]
