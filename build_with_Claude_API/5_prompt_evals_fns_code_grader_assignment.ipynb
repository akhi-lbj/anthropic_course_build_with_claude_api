# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Must include runtime, memory size, timeout, and basic structure for AWS Lambda configuration"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Criteria you should use to evaluate the solution:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    },\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:ListBucket\",\n        \"s3:GetBucketVersioning\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create an IAM policy JSON that allows an EC2 instance to read objects from a specific S3 bucket named 'my-data-bucket'",
#       "format": "json",
#       "solution_criteria": "Must include correct IAM policy structure with Version, Statement array, Effect, Action (s3:GetObject), and Resource ARN pointing to the specific bucket"
#     },
#     "score": 9.0,
#     "reasoning": "The solution meets all stated requirements with correct syntax and structure. The policy properly grants read access to the specified bucket with appropriately scoped ARNs. The inclusion of bucket listing permissions demonstrates practical understanding, though some permissions are broader than the minimal 's3:GetObject' requirement. The policy is secure for the stated use case but slightly over-privileged."
#   },
#   {
#     "output": "\nimport json\nfrom typing import Tuple, Optional\n\ndef extract_cloudwatch_log_data(event: dict) -> Tuple[Optional[str], Optional[int]]:\n    \"\"\"\n    Extracts log message and timestamp from AWS CloudWatch log event.\n    \n    Args:\n        event: CloudWatch log event dictionary\n        \n    Returns:\n        Tuple of (message, timestamp) where timestamp is in milliseconds\n    \"\"\"\n    message = event.get('message')\n    timestamp = event.get('timestamp')\n    \n    return message, timestamp\n\n\ndef extract_from_cloudwatch_logs_event(event: dict) -> list:\n    \"\"\"\n    Extracts log messages and timestamps from CloudWatch Logs event (batch).\n    \n    Args:\n        event: CloudWatch Logs event with logEvents\n        \n    Returns:\n        List of tuples containing (message, timestamp)\n    \"\"\"\n    results = []\n    \n    log_events = event.get('awslogs', {}).get('data', {})\n    if isinstance(log_events, str):\n        import gzip\n        import base64\n        log_events = json.loads(gzip.decompress(base64.b64decode(log_events)))\n    \n    for log_event in log_events.get('logEvents', []):\n        message = log_event.get('message')\n        timestamp = log_event.get('timestamp')\n        results.append((message, timestamp))\n    \n    return results\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS CloudWatch log event and extracts the log message and timestamp",
#       "format": "python",
#       "solution_criteria": "Must parse the CloudWatch Logs event structure, extract 'message' and 'timestamp' fields from the log data, and return them as a dictionary"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates good understanding of AWS CloudWatch Logs event structure, including the compressed data handling. However, it has a critical mismatch with the stated requirements: the criteria explicitly require returning dictionaries, but the functions return tuples. Additionally, production-grade code handling AWS events should include error handling for various failure modes. The functions work correctly for valid inputs but are fragile for edge cases."
#   },
#   {
#     "output": "\n^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9])?$\n",
#     "test_case": {
#       "task": "Create a regular expression to validate AWS S3 bucket names according to AWS naming rules (lowercase letters, numbers, hyphens, 3-63 characters)",
#       "format": "regex",
#       "solution_criteria": "Must enforce lowercase alphanumeric and hyphen characters only, enforce 3-63 character length, and not allow starting or ending with hyphens"
#     },
#     "score": 8.0,
#     "reasoning": "The regex demonstrates strong understanding of the non-hyphen anchoring requirement and character set restrictions. However, it has a critical flaw: the optional group allows single characters (e.g., 'a', 'ab') to match, failing the 3-character minimum. A corrected version would be `^[a-z0-9]([a-z0-9-]{1,61}[a-z0-9]|[a-z0-9])$` to handle both 2-63 character cases properly, or more simply `^[a-z0-9][a-z0-9-]{1,61}[a-z0-9]$|^[a-z0-9]{3}$`."
#   }
# ]
